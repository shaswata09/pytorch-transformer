# %%
from pathlib import Path
import torch
import torch.nn as nn
from config import get_config, latest_weights_file_path
from train import get_model, get_ds, run_validation
from translate import translate
# Out:
# Using device: cuda
# /media/shaswata/4TB_1/Projects/transformer_umar/pytorch-transformer/translate.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_filename)
#     SOURCE: --f=/home/shaswata/.local/share/jupyter/runtime/kernel-v342a63028c1c90b0c6ad835413243cd3449519cf7.json
#  PREDICTED:        লোকজন  লোকটি এক পার হচ্ছে

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
config = get_config()
train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = latest_weights_file_path(config)
state = torch.load(model_filename)
model.load_state_dict(state['model_state_dict'])
# Out:
# Using device: cuda
# Max length of source sentence: 40
# Max length of target sentence: 36
# /tmp/ipykernel_69284/1575033556.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_filename)
# <All keys matched successfully>

# %%
run_validation(model, val_dataloader, tokenizer_src, tokenizer_tgt, config['seq_len'], device, lambda msg: print(msg), 0, None, num_examples=10)
# Out:
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: a white dog wearing reindeer ears is next to a brown dog .
#     TARGET: খেলনা কান পরিহিত এক সাদা কুকুরের পাশে আরেকটি বাদামি কুকুর ।
#  PREDICTED: একটি সাদা কুকুর একটি বাদামি কুকুরের পাশে আরেকটি বাদামি কুকুর ।
# --------------------------------------------------------------------------------
#     SOURCE: young people sit on the grass near a crooked tree with pink blossoms .
#     TARGET: লোকজন গোলাপি ফুল ওয়ালা গাছের নিচে বসে আছে
#  PREDICTED: লোকজন গোলাপি ফুল ওয়ালা গাছের নিচে বসে আছে
# --------------------------------------------------------------------------------
#     SOURCE: a dog is on a leash by a tree
#     TARGET: একটি কুকুর গাছের পাশে দড়ি দিয়ে বাঁধা
#  PREDICTED: একটি কুকুর গাছের পাশে দড়ি দিয়ে বাঁধা
# --------------------------------------------------------------------------------
#     SOURCE: there are two men riding bicycles outside in the snow covered countryside .
#     TARGET: বরফ ঢাকা পল্লীতে দু'জন বাইসাইকেল চালক রয়েছেন।
#  PREDICTED: বরফ ঢাকা দু ' জন বাইসাইকেল চালক রয়েছেন ।
# --------------------------------------------------------------------------------
#     SOURCE: three people dance together to prepare for a show
#     TARGET: একটি অনুষ্ঠানের জন্য তিনজন একসাথে নাচেন
#  PREDICTED: তিনজন লোক একসাথে নাচেন
# --------------------------------------------------------------------------------
#     SOURCE: a brown and white dog is running .
#     TARGET: একটি বাদামী-সাদা কুকুর দৌড়াচ্ছে
#  PREDICTED: একটি বাদামী এবং সাদা কুকুর ছুটে চলেছে ।
# --------------------------------------------------------------------------------
#     SOURCE: the woman is standing up on a bicycle riding through a city .
#     TARGET: একজন মহিলা শহরের রাস্তায় তার সাইকেল চালাচ্ছে
#  PREDICTED: এক নারী শহুরে এলাকায় দাঁড়িয়ে আছে ।
# --------------------------------------------------------------------------------
#     SOURCE: a man carries a sign while standing in the rain .
#     TARGET: বৃষ্টির মাঝে একটি লোক একটা চিহ্ন হাতে দাঁড়িয়ে
#  PREDICTED: বৃষ্টির সময় একজন লোক একটি চিহ্ন নিয়ে দাড়িয়ে আছে
# --------------------------------------------------------------------------------
#     SOURCE: two white dogs are running alongside one another next to a fence .
#     TARGET: একটি বেড়ার পাশে দুটি সাদা কুকুর একে অপরের পাশে দৌড়াচ্ছে।
#  PREDICTED: একটি বেড়ার পাশে দুটি সাদা কুকুর একে অপরের পাশে দৌড়াচ্ছে ।
# --------------------------------------------------------------------------------
#     SOURCE: a man is sitting on top of a snow covered mountaintop .
#     TARGET: তুষারে আচ্ছাদিত পর্বতের চূড়ায় এক ব্যাক্তি বসে আছে
#  PREDICTED: একজন লোক তুষারাবৃত পর্বতের চূড়ায় বসে আছে
# --------------------------------------------------------------------------------

# %%
t = translate("How come a man jump into a swimming pool from the diving board?")
# Out:
# Using device: cuda
# /media/shaswata/4TB_1/Projects/transformer_umar/pytorch-transformer/translate.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_filename)
#     SOURCE: How come a man jump into a swimming pool from the diving board?
#  PREDICTED:  একজন  ডাইভিং ব্যক্তি একটি ব্যক্তি একটি পুলের পুলের একটি সুইমিং পুলে ঝাঁপিয়ে পুলে ঝাঁপিয়ে পড়ে

# %%
t = translate(34)
